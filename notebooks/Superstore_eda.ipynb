# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-030a57fd-668a-405c-bde1-fb0c7ff415e0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-030a57fd-668a-405c-bde1-fb0c7ff415e0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df= pd.read_excel("sample_-_superstore.xls")

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  US-2023-103800 2023-01-03 2023-01-07  Standard Class    DP-13000
# 1       2  US-2023-112326 2023-01-04 2023-01-08  Standard Class    PO-19195
# 2       3  US-2023-112326 2023-01-04 2023-01-08  Standard Class    PO-19195
# 3       4  US-2023-112326 2023-01-04 2023-01-08  Standard Class    PO-19195
# 4       5  US-2023-141817 2023-01-05 2023-01-12  Standard Class    MB-18085
#
#    Customer Name      Segment Country/Region          City  ... Postal Code  \
# 0  Darren Powers     Consumer  United States       Houston  ...       77095
# 1  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 2  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 3  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 4     Mick Brown     Consumer  United States  Philadelphia  ...       19143
#
# ...

# %%
df.shape
# Out:
# (10194, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          10194 non-null  int64
#  1   Order ID        10194 non-null  object
#  2   Order Date      10194 non-null  datetime64[ns]
#  3   Ship Date       10194 non-null  datetime64[ns]
#  4   Ship Mode       10194 non-null  object
#  5   Customer ID     10194 non-null  object
#  6   Customer Name   10194 non-null  object
#  7   Segment         10194 non-null  object
#  8   Country/Region  10194 non-null  object
#  9   City            10194 non-null  object
#  10  State/Province  10194 non-null  object
#  11  Postal Code     10194 non-null  object
#  12  Region          10194 non-null  object
#  13  Product ID      10194 non-null  object
#  14  Category        10194 non-null  object
#  15  Sub-Category    10194 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country/Region    0
# City              0
# State/Province    0
# Postal Code       0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# dtype: int64

# %%
df.describe()
# Out:
#              Row ID                     Order Date  \
# count  10194.000000                          10194
# mean    5097.500000  2025-04-29 11:48:25.002942720
# min        1.000000            2023-01-03 00:00:00
# 25%     2549.250000            2024-05-14 00:00:00
# 50%     5097.500000            2025-06-25 00:00:00
# 75%     7645.750000            2026-05-14 00:00:00
# max    10194.000000            2026-12-30 00:00:00
# std     2942.898656                            NaN
#
#                            Ship Date         Sales      Quantity  \
# count                          10194  10194.000000  10194.000000
# mean   2025-05-03 10:52:45.626839296    228.225854      3.791838
# min              2023-01-07 00:00:00      0.444000      1.000000
# 25%              2024-05-19 00:00:00     17.220000      2.000000
# 50%              2025-06-28 00:00:00     53.910000      3.000000
# 75%              2026-05-18 00:00:00    209.500000      5.000000
# ...

# %%
df.columns.tolist()
# Out:
# ['Row ID',
#  'Order ID',
#  'Order Date',
#  'Ship Date',
#  'Ship Mode',
#  'Customer ID',
#  'Customer Name',
#  'Segment',
#  'Country/Region',
#  'City',
#  'State/Province',
#  'Postal Code',
#  'Region',
#  'Product ID',
#  'Category',
#  'Sub-Category',
#  'Product Name',
#  'Sales',
#  'Quantity',
#  'Discount',
#  'Profit']

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Segment'].unique()
# Out:
# array(['Consumer', 'Home Office', 'Corporate'], dtype=object)

# %%
df['Region'].unique()
# Out:
# array(['Central', 'East', 'South', 'West'], dtype=object)

# %%
df['Category'].unique()
# Out:
# array(['Office Supplies', 'Furniture', 'Technology'], dtype=object)

# %%
df['Ship Mode'].unique()
# Out:
# array(['Standard Class', 'First Class', 'Second Class', 'Same Day'],
#       dtype=object)

# %%
df[['Sales','Quantity','Discount','Profit']].describe()
# Out:
#               Sales      Quantity      Discount        Profit
# count  10194.000000  10194.000000  10194.000000  10194.000000
# mean     228.225854      3.791838      0.155385     28.673417
# std      619.906839      2.228317      0.206249    232.465115
# min        0.444000      1.000000      0.000000  -6599.978000
# 25%       17.220000      2.000000      0.000000      1.760800
# 50%       53.910000      3.000000      0.200000      8.690000
# 75%      209.500000      5.000000      0.200000     29.297925
# max    22638.480000     14.000000      0.800000   8399.976000

# %%
df['Year']= df['Order Date'].dt.year
df['Month']= df['Order Date'].dt.month
df['Month_Name']= df['Order Date'].dt.month_name()

# %%
df[['Order Date','Year','Month','Month_Name']].head()
# Out:
#   Order Date  Year  Month Month_Name
# 0 2023-01-03  2023      1    January
# 1 2023-01-04  2023      1    January
# 2 2023-01-04  2023      1    January
# 3 2023-01-04  2023      1    January
# 4 2023-01-05  2023      1    January

# %%
total_sales= df['Sales'].sum()
total_profit= df['Profit'].sum()
total_Quantity= df['Quantity'].sum()
total_orders= df['Order ID'].nunique()
total_customers= df['Customer ID'].nunique()
totalCustomers_name= df['Customer Name'].nunique()

# %%
print("Total sales:", total_sales)
print("Total Profit:", total_profit)
print("Total Quantity:", total_Quantity)
print("Total Orders:", total_orders)
print("Total Customers:", total_customers)
print("Total Customers by name:", totalCustomers_name)
# Out:
# Total sales: 2326534.3543
# Total Profit: 292296.8145999999
# Total Quantity: 38654
# Total Orders: 5111
# Total Customers: 804
# Total Customers by name: 800

# %%
df.groupby("Customer ID")['Customer Name'].nunique().sort_values(ascending=False).head(10)
# Out:
# Customer ID
# ZD-21925    1
# AA-10315    1
# AA-10375    1
# AA-10480    1
# VD-21670    1
# VB-21745    1
# TZ-21580    1
# TW-21025    1
# TT-21460    1
# TT-21265    1
# Name: Customer Name, dtype: int64

# %%
df.groupby("Customer Name")['Customer ID'].nunique().sort_values(ascending=False).head(10)
# Out:
# Customer Name
# Harry Olson          5
# Melanie Seite        1
# Michael Chen         1
# Michael Dominguez    1
# Michael Grace        1
# Michael Granlund     1
# Michael Kennedy      1
# Michael Knudson      1
# Michael Moore        1
# Michael Nguyen       1
# Name: Customer ID, dtype: int64

# %%
nameIdCheck= (df.groupby("Customer Name")['Customer ID'].nunique().sort_values(ascending=False))
nameIdCheck[nameIdCheck>1]
#
# Out:
# Customer Name
# Harry Olson    5
# Name: Customer ID, dtype: int64

# %%
nameIdCheck[nameIdCheck>1].count()
# Out:
# np.int64(1)

# %%
df[df['Customer Name']=='Harry Olson'][['Customer ID','Customer Name']].drop_duplicates()
# Out:
#      Customer ID Customer Name
# 2036    HO-15230   Harry Olson
# 5009    HO-15234   Harry Olson
# 5010    HO-15233   Harry Olson
# 5011    HO-15232   Harry Olson
# 5012    HO-15231   Harry Olson

# %%
df[df['Customer Name']=='Harry Olson'][['Customer ID','Customer Name','City','State/Province','Postal Code', 'Region']].drop_duplicates()
# Out:
#      Customer ID Customer Name           City        State/Province  \
# 2036    HO-15230   Harry Olson  Charlottetown  Prince Edward Island
# 5009    HO-15234   Harry Olson  Charlottetown  Prince Edward Island
# 5010    HO-15233   Harry Olson  Charlottetown  Prince Edward Island
# 5011    HO-15232   Harry Olson  Charlottetown  Prince Edward Island
# 5012    HO-15231   Harry Olson  Charlottetown  Prince Edward Island
#
#      Postal Code Region
# 2036         C0A   East
# 5009         C0A   East
# 5010         C0A   East
# 5011         C0A   East
# 5012         C0A   East

# %% [markdown]
# there is a customer identifer inconsistency in the source dataset but  the CUSTOMER ID will serve as my primary identifier because it uniquely identify customers accounts

# %%
# Overall profit margin
profit_margin= (total_profit/total_sales)*100
print("Overall profit margin:", round(profit_margin, 2), '%')
# Out:
# Overall profit margin: 12.56 %

# %%
# Sales/ Profit by year
df.groupby('Year')[['Sales','Profit']].sum()
# Out:
#             Sales      Profit
# Year
# 2023  494040.2121  51684.2957
# 2024  472993.0310  62020.9695
# 2025  613933.5800  82665.2018
# 2026  745567.5312  95926.3476

# %%
# sales/ Profit by category
df.groupby('Category')[['Sales','Profit']].sum().sort_values(by='Sales', ascending=False)
# Out:
#                        Sales       Profit
# Category
# Technology       839893.2790  146543.3756
# Furniture        754747.7613   19729.9956
# Office Supplies  731893.3140  126023.4434

# %%
# sales/profit by region
df.groupby('Region')[['Sales','Profit']].sum().sort_values(by='Sales', ascending=False)
# Out:
#                Sales       Profit
# Region
# West     739813.6085  110798.8170
# East     691828.1680   94883.2603
# Central  503170.6728   39865.3070
# South    391721.9050   46749.4303

# %%
df.groupby('Region')[['Discount','Profit']].mean().sort_values(by='Profit', ascending=False)
# Out:
#          Discount     Profit
# Region
# West     0.108946  34.060503
# East     0.143436  31.776042
# South    0.147253  28.857673
# Central  0.241002  17.072937

# %%
df.groupby('Category')[['Discount','Profit']].mean().sort_values(by='Discount', ascending=False)
# Out:
#                  Discount     Profit
# Category
# Furniture        0.172962   8.964105
# Office Supplies  0.156348  20.565183
# Technology       0.131475  78.575537

# %%
df[df['Region']=='Central'].groupby('Category')[['Discount','Profit','Sales']].mean().sort_values(by='Discount', ascending=False)
# Out:
#                  Discount     Profit       Sales
# Category
# Furniture        0.297402  -5.777746  339.252890
# Office Supplies  0.253566   6.272784  117.634062
# Technology       0.133095  80.231981  405.753124

# %%
df[df['Region']=='Central'].groupby('Sub-Category')[['Discount','Profit','Sales']].sum().sort_values(by='Profit', ascending=False)
# Out:
#               Discount      Profit       Sales
# Sub-Category
# Copiers           1.80  15608.8413  37259.5700
# Phones           24.40  12323.0267  72403.2820
# Accessories      22.80   7251.6306  33956.0760
# Paper            41.40   6971.9005  17491.9020
# Chairs           30.10   6670.8633  85941.1420
# Storage          26.40   1974.6065  45982.8980
# Envelopes         7.60   1777.5283   4636.8720
# Art              21.60   1195.1591   5765.3400
# Labels            8.60   1073.0794   2451.4720
# Fasteners         7.40    236.6186    778.0300
# Supplies          5.20   -661.8881   9467.3720
# Binders         189.20   -958.3051  58060.7900
# Machines          6.90  -1486.0666  26797.3840
# Bookcases        11.64  -1997.9043  24157.1768
# Appliances       55.20  -2638.6175  23582.0330
# Tables           18.90  -3559.6504  39154.9710
# Furnishings      83.60  -3915.5153  15284.3620

# %%
df[(df['Region']=='Central') & (df['Category']=='Furniture')].groupby('Product Name')[['Discount','Profit','Sales']].mean().sort_values(by='Profit', ascending=False)
# Out:
#                                                     Discount    Profit  \
# Product Name
# Hon Pagoda Stacking Chairs                               0.0  770.3520
# Office Star - Professional Matrix Back Chair wi...       0.0  673.8816
# Hon Olson Stacker Stools                                 0.0  394.2680
# Hon Olson Stacker Chairs                                 0.0  383.9310
# Hon Deluxe Fabric Upholstered Stacking Chairs, ...       0.0  365.9700
# ...                                                      ...       ...
# Luxo Professional Fluorescent Magnifier Lamp wi...       0.6 -356.7280
# Tenex Antistatic Computer Chair Mats                     0.6 -427.4500
# Hon Rectangular Conference Tables                        0.5 -525.6405
# Bretford “Just In Time” Height-Adjustable Multi...       0.5 -538.4460
# BoxOffice By Design Rectangular and Half-Moon M...       0.5 -566.5625
#
#                                                        Sales
# Product Name
# ...

# %%
# Investigating negative-profit products
df[df['Profit']<0][['Product Name','Sales','Discount','Profit']].sort_values(by='Profit').head(20)
# Out:
#                                            Product Name      Sales  Discount  \
# 6398          Cubify CubeX 3D Printer Double Head Print   4499.985       0.7
# 9318          Cubify CubeX 3D Printer Triple Head Print   7999.980       0.5
# 821           GBC DocuBind P400 Electric Binding System   2177.584       0.8
# 7441          Lexmark MX611dhe Monochrome Laser Printer   2549.985       0.7
# 9845               Ibico EPK-21 Electric Binding System   1889.990       0.8
# 4037          Cubify CubeX 3D Printer Double Head Print   1799.994       0.7
# 9557  Fellowes PB500 Electric Punch Plastic Comb Bin...   1525.188       0.8
# 2108  Chromcraft Bull-Nose Wood Oval Conference Tabl...   4297.644       0.4
# 4570          GBC DocuBind P400 Electric Binding System   1088.792       0.8
# 226   Cisco TelePresence System EX90 Videoconferenci...  22638.480       0.5
# 3203  Riverside Palais Royal Lawyers Bookcase, Royal...   3083.430       0.5
# ...

# %%
df[df['Profit']<0].groupby('Category')[['Sales','Discount','Profit']].mean()
# Out:
#                       Sales  Discount      Profit
# Category
# Furniture        356.107045  0.369590  -84.255715
# Office Supplies  102.856921  0.616147  -63.233662
# Technology       439.899974  0.333579 -142.361322

# %%
df[df['Profit']<0].groupby('Sub-Category')[['Sales','Discount','Profit']].sum().sort_values(by='Profit')
# Out:
#                     Sales  Discount      Profit
# Sub-Category
# Binders        36200.5010    455.70 -38563.4860
# Tables        105699.3760     74.75 -32503.6583
# Machines       72456.2530     25.60 -30118.6682
# Bookcases      48217.3288     39.39 -12349.8096
# Chairs         93460.1680     62.00 -10135.0373
# Appliances      3382.5340     53.60  -8629.6412
# Phones         35797.8400     46.60  -7530.6235
# Furnishings    13293.4840     94.40  -6686.6785
# Storage        38429.1440     32.70  -6480.2220
# Supplies       14067.1760      6.60  -3015.6219
# Accessories    10958.8000     18.20   -930.6265
# Fasteners        149.2800      2.40    -33.1952
# Labels            82.9200      1.10    -31.3860
# Art               39.9600      0.60    -23.9760
# Paper             14.0000      0.60     -6.3000

# %%
df.groupby('Sub-Category')[['Sales','Discount','Profit']].mean().sort_values(by='Discount', ascending=False)
# Out:
#                     Sales  Discount      Profit
# Sub-Category
# Binders        133.950182  0.369057   20.301098
# Machines      1623.290863  0.304274   29.589546
# Tables         638.098718  0.258129  -54.457687
# Bookcases      497.246570  0.215259  -15.655490
# Chairs         529.602916  0.169243   42.939325
# Appliances     228.297859  0.164557   38.669798
# Copiers       2153.504143  0.157143  801.341950
# Phones         367.489081  0.152602   49.890173
# Furnishings     94.745417  0.138057   13.767833
# Envelopes       64.563914  0.079688   27.296971
# Fasteners       37.258690  0.078603   10.605397
# Accessories    215.974604  0.078452   54.111788
# Supplies       243.361969  0.076042   -6.101013
# Storage        262.435227  0.075117   24.865784
# Art             33.689420  0.075030    8.103771
# Paper           57.471487  0.075000   24.936060
# Labels          34.497397  0.070924   15.143418

# %%
df[df['Sub-Category']=='Binders'][['Sales','Discount','Profit']].describe()
# Out:
#              Sales     Discount       Profit
# count  1548.000000  1548.000000  1548.000000
# mean    133.950182     0.369057    20.301098
# std     559.368482     0.311167   303.893602
# min       0.556000     0.000000 -3701.892800
# 25%       8.251500     0.200000    -6.008400
# 50%      18.706500     0.200000     4.123800
# 75%      52.218000     0.700000    16.001300
# max    9892.740000     0.800000  4946.370000

# %%
df[df['Sub-Category']=='Bookcases'].groupby('Discount')['Profit'].mean().sort_index()
# Out:
# Discount
# 0.00    101.261862
# 0.15     27.288298
# 0.20      3.512254
# 0.30    -55.587260
# 0.32    -88.560656
# 0.50   -236.433983
# 0.70   -240.737824
# Name: Profit, dtype: float64

# %%
df[df['Sub-Category']=='Tables'].groupby('Discount')['Profit'].mean().sort_index()
# Out:
# Discount
# 0.00    175.459536
# 0.20     -4.144417
# 0.30    -62.389957
# 0.40   -215.831957
# 0.45   -226.646464
# 0.50   -239.316314
# Name: Profit, dtype: float64

# %%
df[['Discount','Profit']].corr()
# Out:
#           Discount    Profit
# Discount  1.000000 -0.218882
# Profit   -0.218882  1.000000

# %% [markdown]
# ## 5. Profitability Analysis

# %%
# Category profitability
category_analysis=(df.groupby('Category')
.agg(
    Sales=('Sales','sum'),
    Profit=('Profit','sum'),
    Quantity=('Quantity','sum')
    )
)
category_analysis['Profit Margin']= (category_analysis['Profit']/category_analysis['Sales']*100)
category_analysis.sort_values(by='Sales', ascending=False).round(2)
# Out:
#                      Sales     Profit  Quantity  Profit Margin
# Category
# Technology       839893.28  146543.38      7017          17.45
# Furniture        754747.76   19730.00      8369           2.61
# Office Supplies  731893.31  126023.44     23268          17.22

# %%
# sub-category analysis
sub_category_analysis=(df.groupby('Sub-Category')
.agg(
    Sales=('Sales','sum'),
    Profit=('Profit','sum'),
    Quantity=('Quantity','sum')
    )
)
sub_category_analysis['profit Margin']= (sub_category_analysis['Profit']/sub_category_analysis['Sales']*100)
sub_category_analysis.sort_values(by='Profit')
# Out:
#                     Sales      Profit  Quantity  profit Margin
# Sub-Category
# Tables        208020.1820 -17753.2061      1261      -8.534367
# Bookcases     115361.2043  -3632.0736       878      -3.148436
# Supplies       46725.4980  -1171.3945       653      -2.506971
# Fasteners       8532.2400   2428.6358       980      28.464223
# Machines      189925.0310   3461.9769       442       1.822812
# Labels         12695.0420   5572.7780      1410      43.897279
# Art            27659.0140   6653.1962      3092      24.054351
# Envelopes      16528.3620   6988.0247       914      42.278991
# Furnishings    95598.1260  13891.7430      3799      14.531397
# Appliances    108213.1850  18329.4844      1750      16.938310
# Storage       224644.5540  21285.1115      3191       9.475018
# Chairs        335768.2490  27223.5323      2431       8.107834
# Binders       207354.8810  31426.1003      6071      15.155708
# Paper          79540.5380  34511.5070      5207      43.388576
# ...

# %%
# regional profitability
region_analysis=(df.groupby('Region')
.agg(
    Sales=('Sales','sum'),
    Profit=('Profit','sum'),
    Quantity=('Quantity','sum')
    )
)
region_analysis['profit Margin']= (region_analysis['Profit']/region_analysis['Sales']*100)
region_analysis.sort_values(by='Sales', ascending=False).round(2)
# Out:
#              Sales     Profit  Quantity  profit Margin
# Region
# West     739813.61  110798.82     12466          14.98
# East     691828.17   94883.26     11159          13.71
# Central  503170.67   39865.31      8820           7.92
# South    391721.90   46749.43      6209          11.93

# %%
# Create a copy for Tableau
tableau_df= df.copy()

# %%
tableau_df.shape
# Out:
# (10194, 24)

# %%
tableau_df.columns.to_list()
# Out:
# ['Row ID',
#  'Order ID',
#  'Order Date',
#  'Ship Date',
#  'Ship Mode',
#  'Customer ID',
#  'Customer Name',
#  'Segment',
#  'Country/Region',
#  'City',
#  'State/Province',
#  'Postal Code',
#  'Region',
#  'Product ID',
#  'Category',
#  'Sub-Category',
#  'Product Name',
#  'Sales',
#  'Quantity',
#  'Discount',
#  'Profit',
#  'Year',
#  'Month',
#  'Month_Name']

# %%
tableau_df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
#tableau_df['Year_Month']= tableau_df['Order Date'].dt.strftime('%Y-%m') or
tableau_df['Year_Month']= tableau_df['Order Date'].dt.to_period('M').astype(str)

# %%
tableau_df[['Order Date','Year','Month_Name','Year_Month']].head()
# Out:
#   Order Date  Year Month_Name Year_Month
# 0 2023-01-03  2023    January    2023-01
# 1 2023-01-04  2023    January    2023-01
# 2 2023-01-04  2023    January    2023-01
# 3 2023-01-04  2023    January    2023-01
# 4 2023-01-05  2023    January    2023-01

# %%
tableau_df.to_csv('Superstore_Tableau_ready.csv', index=False)

# %%
import os
os.path.getsize('Superstore_Tableau_ready.csv')
# Out:
# 2624554

# %%
from google.colab import files
files.download('Superstore_Tableau_ready.csv')

# %%
# profit contribution by category
category_analysis['profit_contribution']= (category_analysis['Profit']/category_analysis['Profit'].sum()*100)
category_analysis.sort_values(by='profit_contribution', ascending=False).round(2)
# Out:
#                      Sales     Profit  Quantity  Profit Margin  \
# Category
# Technology       839893.28  146543.38      7017          17.45
# Office Supplies  731893.31  126023.44     23268          17.22
# Furniture        754747.76   19730.00      8369           2.61
#
#                  profit_contribution
# Category
# Technology                     50.14
# Office Supplies                43.11
# Furniture                       6.75

# %%
# profit contribution by region
region_analysis['profit_contribution']= (region_analysis['Profit']/region_analysis['Profit'].sum()*100)
region_analysis.sort_values(by='profit_contribution', ascending=False).round(2)
# Out:
#              Sales     Profit  Quantity  profit Margin  profit_contribution
# Region
# West     739813.61  110798.82     12466          14.98                37.91
# East     691828.17   94883.26     11159          13.71                32.46
# South    391721.90   46749.43      6209          11.93                15.99
# Central  503170.67   39865.31      8820           7.92                13.64
